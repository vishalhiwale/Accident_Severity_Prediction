# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalhiwale/Accident_Severity_Prediction/blob/main/DiagnoBot/Clinical_BERT/Clinical_BERT_data_retrieving_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create dataframe from Dictionary

# %%
import pandas as pd

# %%
# @title
data_0 = {
    'Query': [
        "I have been excessively thirsty and losing weight over the last month. Do these sound like diabetes symptoms?",
        "What are the primary indicators that I should look out for that suggest I might have high blood sugar?",
        "My vision has been blurry, and I feel tingling in my feet. Are these common diabetes complaints?",
        "Is persistent tiredness always a sign of Type 2 Diabetes, or could it be something else?",
        "What are the main differences in symptoms between Type 1 and Type 2 Diabetes?",
        "I have to urinate frequently, especially at night. Is this related to my blood sugar levels?",
        "What is the A1C test used for, and what are normal ranges?",
        "My doctor ordered a Fasting Plasma Glucose test. What result indicates a diabetes diagnosis?",
        "Can you explain what an oral glucose tolerance test (OGTT) measures?",
        "What should I do if my home blood glucose meter gives me a wildly different reading than the lab report?",
        "I was recently diagnosed with pre-diabetes. What do those diagnostic numbers mean?",
        "Where can I find my latest HbA1c test results and how should I interpret them?",
        "What is Metformin, and what are its common side effects for a diabetic patient?",
        "I am starting insulin injections. Can you explain the difference between basal and bolus insulin?",
        "What should I do if I forget to take my daily dose of my diabetes medication?",
        "Are there any new non-insulin injectable medications available for Type 2 Diabetes?",
        "Can I stop taking my medication if my A1C levels return to normal?",
        "What is a continuous glucose monitor (CGM) and how does it help with treatment?",
        "What types of food should a person with Type 2 Diabetes avoid completely?",
        "Is white rice strictly off-limits, or can I eat it in moderation with portion control?",
        "How many minutes of exercise per week are recommended to improve insulin sensitivity?",
        "Can I still consume artificial sweeteners, and do they affect my glucose levels?",
        "What is the best way to calculate carbohydrates for a meal when counting carbs?",
        "Are there specific times of day I should eat meals to help manage my condition?",
        "I just tested my blood sugar, and it's 250 mg/dL. What should I do right now?",
        "What are the signs and symptoms of severe low blood sugar (hypoglycemia)?",
        "How often should I be checking my blood glucose levels throughout the day?",
        "My blood sugar is consistently high in the morning. What is the dawn phenomenon?",
        "What steps should I take if my blood sugar is spiking after every meal?",
        "What should my target blood glucose range be before and after eating?",
        "What are the long-term risks associated with uncontrolled high blood sugar (hyperglycemia)?",
        "What is diabetic neuropathy, and what can I do to protect my feet?",
        "Is it true that diabetes can lead to heart disease and kidney failure?",
        "What are the signs of diabetic retinopathy, and how often should I see an eye specialist?",
        "What should I know about my increased risk for foot ulcers and amputations?",
        "How can I reduce the risk of developing nephropathy (kidney damage) over time?",
        "How does diabetes affect the body's ability to heal wounds and fight infections?",
        "What is the difference between Type 1 and Type 2 Diabetes, and why are they named that way?",
        "How common is gestational diabetes, and what are the risks for the baby?",
        "Is diabetes a curable disease, or is it always a chronic, lifelong condition?",
        "Can stress directly impact my blood sugar readings, and how do I manage that?",
        "What resources are available for diabetes support groups and patient education?"
    ],
    'Intent': [
        "symptoms",
        "symptoms",
        "symptoms",
        "symptoms",
        "symptoms",
        "symptoms",
        "diagnosis_and_reports",
        "diagnosis_and_reports",
        "diagnosis_and_reports",
        "diagnosis_and_reports",
        "diagnosis_and_reports",
        "diagnosis_and_reports",
        "treatment_and_medication",
        "treatment_and_medication",
        "treatment_and_medication",
        "treatment_and_medication",
        "treatment_and_medication",
        "treatment_and_medication",
        "lifestyle_and_diet",
        "lifestyle_and_diet",
        "lifestyle_and_diet",
        "lifestyle_and_diet",
        "lifestyle_and_diet",
        "lifestyle_and_diet",
        "blood_sugar_management",
        "blood_sugar_management",
        "blood_sugar_management",
        "blood_sugar_management",
        "blood_sugar_management",
        "blood_sugar_management",
        "complications",
        "complications",
        "complications",
        "complications",
        "complications",
        "complications",
        "general",
        "general",
        "general",
        "general",
        "general",
        "general"
    ]
}

# %%
data_0 = pd.DataFrame(data_0)
print(data_0.head(5),
data_0.shape)
# Out:
#                                                Query    Intent
# 0  I have been excessively thirsty and losing wei...  symptoms
# 1  What are the primary indicators that I should ...  symptoms
# 2  My vision has been blurry, and I feel tingling...  symptoms
# 3  Is persistent tiredness always a sign of Type ...  symptoms
# 4  What are the main differences in symptoms betw...  symptoms (42, 2)

# %%
# @title
data_1 = {
    'Query': [
        # --- 1. symptoms (Expanded: Focus on Specificity and Ambiguity) ---
        "I’m constantly hungry even after large meals. Is this severe hunger (polyphagia) a definite sign of diabetes onset?",
        "My joints have been stiff and I feel chronic muscle pain. Can these non-traditional signs be linked to elevated glucose?",
        "I've been waking up with headaches and night sweats. Is this related to morning blood sugar fluctuations?",
        "My cuts and bruises are taking weeks to heal. How quickly does slow wound healing manifest in pre-diabetes?",
        "I'm feeling very weak, dizzy, and I get out of breath easily. Should I check for dehydration related to high sugar?",
        "What does the medical term 'acanthosis nigricans' mean, and is it always present with insulin resistance?",
        "I’ve noticed a decrease in my ability to smell. Is olfactory dysfunction a documented symptom?",
        "My periods have become irregular since I started gaining weight. Is there a link to PCOS and diabetic symptoms?",
        "Is blurred vision an immediate symptom of a blood sugar spike, or a sign of chronic eye damage?",
        "I feel a constant metallic taste in my mouth, and I am not taking any medication. Could this be related to DKA symptoms?",
        "My skin is extremely itchy, especially on my arms and legs. Is this pruritus linked to poor circulation?",
        "What are the specific symptom differences that differentiate Type 1 from Latent Autoimmune Diabetes in Adults (LADA)?",
        "I had a large carb meal and now feel profoundly sleepy. Is postprandial somnolence a sign of glucose overload?",
        "Can recurrent yeast infections or UTIs be the first noticeable symptom in men?",
        "I have sudden, unexplained weight loss despite eating normally. Is this rapid change typical of Type 1 onset?",
        "I’m experiencing pins and needles in my extremities but only at night. What stage of neuropathy does this suggest?",
        "What are the early warning signs of insulin resistance before full-blown Type 2 Diabetes develops?",
        "Are cold hands and feet a common indicator of circulation problems stemming from high glucose?",
        "My dry mouth is so severe it affects my speaking. What is the clinical term for this level of dehydration?",
        "I'm experiencing numbness and a pins-and-needles feeling in my hands and feet. Is this a common sign of late-stage diabetes?",
        "My gums are often swollen and bleed easily. Is this a lesser-known symptom of high blood sugar?",
        "I have noticed a strong, fruity odor on my breath, and I'm very nauseous. What acute condition does this suggest?",
        "What is the connection between frequent skin infections, slow healing, and undiagnosed diabetes?",
        "I wake up starving in the middle of the night despite having a big dinner. Is that polyphagia?",
        "Lately, I've had extreme fatigue that doesn't go away. Could this be related to insulin resistance?",

        # --- 2. diagnosis_and_reports (Expanded: Focus on Testing and Interpretation) ---
        "What is the difference between impaired fasting glucose and impaired glucose tolerance?",
        "If my doctor suspects I have Type 1, what specific autoantibody tests will they order?",
        "I had a random blood sugar test result of 175 mg/dL. Is that high enough to indicate pre-diabetes?",
        "What are the official diagnostic criteria for gestational diabetes, usually measured during pregnancy?",
        "Does having a high C-peptide level rule out a Type 1 Diabetes diagnosis?",
        "How reliable is the glycated albumin test compared to the standard A1C test?",
        "What is the standard procedure for a Continuous Glucose Monitoring (CGM) sensor insertion?",
        "My fasting blood sugar was 105 mg/dL. Is this considered normal, pre-diabetic, or borderline high?",
        "What are the acceptable HbA1c target levels for an elderly patient with co-morbidities?",
        "Can certain medications, like steroids, temporarily skew my glucose tolerance test results?",
        "What should the normal results for a urine microalbumin test be, and what does a high result mean?",
        "How do I accurately calculate the estimated average glucose (eAG) from my A1C percentage?",
        "What is the significance of the Glutamic Acid Decarboxylase Autoantibodies (GADA) test?",
        "What documentation or report should I bring to my first consultation with a diabetologist?",
        "If I'm using a CGM, what is the best metric to share with my doctor: Time in Range or GMI?",
        "Is there a blood test that can conclusively distinguish between Type 1 and Type 2 Diabetes?",
        "What should the results of a 75-gram oral glucose tolerance test look like for a non-diabetic person?",
        "What factors might lead to a false positive result on a basic urine glucose strip test?",
        "Is there a minimum age requirement for receiving a definitive Type 2 Diabetes diagnosis?",
        "Where can I find my latest HbA1c test results and how should I interpret them?",
        "I was recently diagnosed with pre-diabetes. What do those diagnostic numbers mean?",
        "What should I do if my home blood glucose meter gives me a wildly different reading than the lab report?",
        "Can you explain what an oral glucose tolerance test (OGTT) measures?",
        "My doctor ordered a Fasting Plasma Glucose test. What result indicates a diabetes diagnosis?",
        "What is the A1C test used for, and what are normal ranges?",

        # --- 3. treatment_and_medication (Expanded: Focus on Dosing, Delivery, Side Effects) ---
        "Can you detail the mechanism of action for SGLT2 inhibitors like Jardiance?",
        "I use a pen injector for Trulicity. Where is the best place on my body to inject it for maximum effect?",
        "What are the typical side effects of basal insulin like Lantus or Tresiba?",
        "I want to transition from a twice-daily insulin regimen to an intensive basal-bolus regimen. What are the key differences?",
        "What criteria do doctors use to decide if a Type 2 patient should be switched from oral medications to insulin?",
        "My pharmacist said I should use a new inhaled insulin. What are the pros and cons of that delivery method?",
        "What is the standard starting dose for Metformin for a newly diagnosed adult?",
        "How do I determine the correct insulin-to-carb ratio (ICR) for my rapid-acting insulin?",
        "Can skipping meals while on Sulfonylureas lead to dangerously low blood sugar?",
        "I am experiencing severe nausea after starting GLP-1 agonists. What is the standard advice for managing this?",
        "What are the specific steps for rotating injection sites to prevent lipohypertrophy?",
        "Are there any drug interactions between blood pressure medications and diabetes treatment like Metformin?",
        "What is the basal rate setting used for in an insulin pump, and how is it calculated?",
        "How long does it take for medications like Ozempic to reach their full blood-sugar-lowering effect?",
        "What are the rules regarding driving while taking insulin, particularly concerning hypoglycemia risk?",
        "Can I crush or split my Januvia tablet if I have difficulty swallowing pills?",
        "What is a continuous glucose monitor (CGM) and how does it help with treatment?",
        "Can I stop taking my medication if my A1C levels return to normal?",
        "Are there any new non-insulin injectable medications available for Type 2 Diabetes?",
        "What should I do if I forget to take my daily dose of my diabetes medication?",
        "I am starting insulin injections. Can you explain the difference between basal and bolus insulin?",
        "What is Metformin, and what are its common side effects for a diabetic patient?",
        "What are the best practices for storing and traveling with insulin in hot climates?",
        "How often should the lancet device be changed when performing fingerstick blood checks?",
        "What are the signs of an allergic reaction to a new type of insulin?",

        # --- 4. lifestyle_and_diet (Expanded: Focus on Specific Foods and Exercise) ---
        "What is the glycemic index (GI) and how should I use it to choose my daily carbohydrates?",
        "Are complex carbohydrates like whole-grain bread better than simple sugars because of fiber content?",
        "How should I adjust my meal plan and insulin dosage on days when I plan intense cardio exercise?",
        "I’ve heard intermittent fasting can help with insulin sensitivity. What are the safest protocols for a diabetic?",
        "Should I prioritize consuming healthy fats over protein to keep my blood sugar stable?",
        "Can a diabetic patient consume moderate amounts of alcohol, and if so, how does it affect blood sugar?",
        "Is there a specific 'diabetic diet' recommended by the ADA, or is it individualized?",
        "How do I calculate the carbohydrate content of a meal that contains mixed ingredients like a casserole?",
        "What is the recommended timing for taking a walk after eating a large meal to control glucose spike?",
        "Can consuming probiotics or fermented foods help improve overall glucose control?",
        "What specific exercises are most effective for building lean muscle mass to boost metabolism?",
        "Should I completely eliminate sugar from my coffee, or can I use natural alternatives like stevia?",
        "How do different types of fiber (soluble vs. insoluble) affect the rate of glucose absorption?",
        "What are some safe, diabetic-friendly snacks I can keep at my desk for emergency hypoglycemia?",
        "Is it safer to exercise in the morning or the evening when managing Type 1 Diabetes?",
        "What are the nutritional facts I must check on a food label besides the total carbohydrates?",
        "How does chronic lack of sleep or shift work affect my blood glucose control and appetite?",
        "Are there specific vitamins or supplements (e.g., Chromium, Magnesium) recommended for diabetics?",
        "What should my plate look like using the 'Plate Method' for portion control?",
        "What are some low-carb alternatives to pasta and bread that are easy to prepare?",
        "Are there specific times of day I should eat meals to help manage my condition?",
        "What is the best way to calculate carbohydrates for a meal when counting carbs?",
        "Can I still consume artificial sweeteners, and do they affect my glucose levels?",
        "How many minutes of exercise per week are recommended to improve insulin sensitivity?",
        "Is white rice strictly off-limits, or can I eat it in moderation with portion control?",

        # --- 5. blood_sugar_management (Expanded: Focus on Numbers, Patterns, and Technology) ---
        "My blood sugar dropped below 55 mg/dL. What immediate steps should I take beyond the 15-15 rule?",
        "I am consistently getting hyperglycemia spikes right after I wake up. What could be causing the Somogyi effect?",
        "How do I calibrate my Continuous Glucose Monitor (CGM) sensor for the most accurate readings?",
        "My doctor wants me to keep a log of my blood sugar readings. What data points are most essential to record?",
        "What are the emergency warning signs that indicate I need to go to the hospital for DKA (Diabetic Ketoacidosis)?",
        "If I am sick with the flu, how should I manage my blood sugar and insulin dosages?",
        "What is the ideal blood glucose target range for a patient during a hospital stay or surgery?",
        "How does altitude affect blood glucose readings, and should I adjust my insulin when traveling?",
        "I'm using a pump, and my blood sugar is suddenly high. What is the first thing I should check for a pump failure?",
        "What is 'time in range,' and why is it a better metric than just the A1C for management?",
        "What are the signs of rebound hyperglycemia after treating a low blood sugar event?",
        "How do I manually calculate my correction factor (or insulin sensitivity factor) for high glucose levels?",
        "I just tested my blood sugar, and it's 350 mg/dL. What is the maximum safe correctional dose of insulin I can take?",
        "What is the difference between blood glucose and plasma glucose readings?",
        "Should I check my glucose more often when I am stressed or emotionally upset?",
        "What temperature changes can cause my blood sugar to fluctuate unexpectedly?",
        "What are the guidelines for checking for ketones, and when is it necessary?",
        "What should my target blood glucose range be before and after eating?",
        "What steps should I take if my blood sugar is spiking after every meal?",
        "My blood sugar is consistently high in the morning. What is the dawn phenomenon?",
        "How often should I be checking my blood glucose levels throughout the day?",
        "What are the signs and symptoms of severe low blood sugar (hypoglycemia)?",
        "I just tested my blood sugar, and it's 250 mg/dL. What should I do right now?",
        "What is the danger zone for blood glucose readings that requires immediate medical attention?",
        "My CGM shows a rapid drop arrow. What steps should I take preemptively before the low hits?",

        # --- 6. complications (Expanded: Focus on Prevention and Chronic Damage) ---
        "I have microalbuminuria. What preventative measures are taken to slow the progression of diabetic kidney disease?",
        "Can diabetes cause hearing loss, and if so, what is the physiological mechanism?",
        "What steps should a diabetic take to prevent foot ulcers and manage existing diabetic neuropathy?",
        "I am a woman with Type 1 Diabetes. What are the specific risks and management strategies for a pregnancy?",
        "What are the symptoms of gastroparesis, and what dietary changes can manage this complication?",
        "What is the risk of stroke or heart attack for a person with long-standing, poorly controlled diabetes?",
        "How often should a diabetic patient have a comprehensive foot exam by a podiatrist?",
        "What are the stages of diabetic retinopathy, and when is laser surgery recommended?",
        "What medications are used to manage diabetic hypertension to protect the kidneys?",
        "I have a non-healing cut on my toe. Should I use antibiotic ointment, or is specialized care needed?",
        "Can tightly controlled blood sugar reverse the effects of early-stage diabetic neuropathy?",
        "What are the dietary restrictions for a patient who has progressed to end-stage renal disease (ESRD)?",
        "How does diabetes increase my susceptibility to pneumonia and influenza?",
        "What are the signs of silent heart attack specific to diabetic patients with neuropathy?",
        "I'm worried about diabetic dermopathy (skin spots). Are they dangerous, or just cosmetic?",
        "How can I ensure my shoes are appropriate to prevent pressure points and blisters?",
        "What is Charcot's arthropathy, and what are the warning signs in the feet?",
        "What are the long-term risks associated with uncontrolled high blood sugar (hyperglycemia)?",
        "What is diabetic neuropathy, and what can I do to protect my feet?",
        "Is it true that diabetes can lead to heart disease and kidney failure?",
        "What are the signs of diabetic retinopathy, and how often should I see an eye specialist?",
        "What should I know about my increased risk for foot ulcers and amputations?",
        "How can I reduce the risk of developing nephropathy (kidney damage) over time?",
        "What preventative steps should I take before traveling by plane to avoid complications?",
        "Does diabetes increase the risk of developing cataracts or glaucoma?",

        # --- 7. general (Expanded: Focus on Lifestyle, Research, and Support) ---
        "What legal protections and accommodations are available in the workplace for employees managing diabetes?",
        "How does the immune system of a person with diabetes differ from that of a non-diabetic person?",
        "Are children who are born to diabetic mothers at higher risk for developing the condition later in life?",
        "What is the average life expectancy for a person diagnosed with Type 2 Diabetes at age 40?",
        "Where can I find emotional support groups or therapy specifically for dealing with diabetes burnout?",
        "What are some common myths about diabetes that I should be aware of?",
        "Is there a link between obesity and the body's ability to produce or use insulin effectively?",
        "What current research is being done on a potential cure or a functional cure for Type 1 Diabetes?",
        "What steps should family members take to support a newly diagnosed adult diabetic?",
        "How does hormonal birth control affect blood sugar levels in women with diabetes?",
        "Are there any financial assistance programs or grants for purchasing insulin or CGMs?",
        "What is the role of a Certified Diabetes Care and Education Specialist (CDCES)?",
        "Can chronic stress elevate cortisol levels, thereby making blood sugar management harder?",
        "What is the genetic risk if both my parents have Type 2 Diabetes?",
        "What are the risks of using outdated or expired test strips for my glucose meter?",
        "Should I inform my dentist and other non-diabetic doctors about my condition?",
        "What are the key findings from the latest Diabetes Control and Complications Trial (DCCT)?",
        "What is the recommended screening schedule for family members of people with Type 1 Diabetes?",
        "How does diabetes affect the body's ability to heal wounds and fight infections?",
        "What is the difference between Type 1 and Type 2 Diabetes, and why are they named that way?",
        "How common is gestational diabetes, and what are the risks for the baby?",
        "Is diabetes a curable disease, or is it always a chronic, lifelong condition?",
        "Can stress directly impact my blood sugar readings, and how do I manage that?",
        "What resources are available for diabetes support groups and patient education?",
        "What is the general recommended vaccination schedule for a diabetic adult?"
    ],
    'Intent': [
        "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms",
        "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms",
        "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms",
        "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms",

        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",
        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",
        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",
        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",
        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",
        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",
        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",
        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",

        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",
        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",
        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",
        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",
        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",
        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",
        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",
        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",

        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",
        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",
        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",
        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",
        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",
        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",
        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",
        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",

        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",
        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",
        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",
        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",
        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",
        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",
        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",
        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",

        "complications", "complications", "complications",
        "complications", "complications", "complications",
        "complications", "complications", "complications",
        "complications", "complications", "complications",
        "complications", "complications", "complications",
        "complications", "complications", "complications",
        "complications", "complications", "complications",
        "complications", "complications", "complications", "complications",

        "general", "general", "general",
        "general", "general", "general",
        "general", "general", "general",
        "general", "general", "general",
        "general", "general", "general",
        "general", "general", "general",
        "general", "general", "general",
        "general", "general", "general", "general"
    ]
}

# %%
data_1 = pd.DataFrame(data_1)
print(data_1.head(5),
data_1.shape)
# Out:
#                                                Query    Intent
# 0  I’m constantly hungry even after large meals. ...  symptoms
# 1  My joints have been stiff and I feel chronic m...  symptoms
# 2  I've been waking up with headaches and night s...  symptoms
# 3  My cuts and bruises are taking weeks to heal. ...  symptoms
# 4  I'm feeling very weak, dizzy, and I get out of...  symptoms (175, 2)

# %%
# @title
data_2 = {
    'Query': [
        # --- 1. SYMPTOMS (Real Patient Phrasing) ---
        "I'm literally thirsty all the time, I drank 3 liters of water today and my mouth still feels like cotton.",
        "My vision gets super blurry specifically after I eat a big dinner, is that a sugar spike?",
        "I've been peeing like a racehorse every hour, even waking up 4-5 times a night.",
        "My feet feel like they are burning or on fire when I try to sleep.",
        "I have this weird fruity taste in my mouth and my breath smells like nail polish remover.",
        "I lost 15 pounds in two weeks without even trying or hitting the gym, should I be worried?",
        "Cuts on my legs just won't heal, I've had this scab for a month now.",
        "I feel shaky and 'hangry' if I don't eat every 3 hours, almost like I'm going to pass out.",
        "My skin is so dry and itchy, lotion isn't helping at all.",
        "I'm exhausted no matter how much sleep I get, it's a bone-deep fatigue.",
        "Noticed dark velvety patches on my neck and armpits, look like dirt but won't wash off.",
        "Got another yeast infection, that's the third one this month.",
        "My hands feel tingly and numb when I hold my phone for too long.",
        "I feel nauseous and have been vomiting, my stomach hurts so bad.",
        "Mood swings are crazy lately, I snap at everyone when I'm hungry.",
        "Is it normal to be hungry immediately after finishing a huge meal?",
        "My 5-year-old is wetting the bed again after being potty trained for years.",
        "Breath smells sweet, kind of like juicy fruit gum.",
        "Feeling dizzy and lightheaded whenever I stand up quickly.",
        "I have pins and needles sensation in my toes that won't go away.",
        "My doctor mentioned 'acanthosis nigricans', is that the dark skin on my knuckles?",
        "I feel like I have the flu but without a fever, just weak and achy.",

        # --- 2. DIAGNOSIS & REPORTS (Lab Results & Confusion) ---
        "Just got my bloodwork back, A1C is 8.4, how bad is that?",
        "My fasting glucose was 126 exactly, does that technically make me diabetic?",
        "Failed the 3-hour glucose tolerance test during pregnancy, what now?",
        "Doc says I'm 'pre-diabetic' with an A1C of 5.9, can I reverse this?",
        "What does 'eAG 180' mean on my lab report?",
        "Urinalysis showed +3 glucose and trace ketones, is that an emergency?",
        "My home meter says 200 but the lab says 150, which one do I trust?",
        "Diagnosed with LADA but my doctor keeps treating me like Type 2.",
        "C-Peptide came back low, does that confirm Type 1?",
        "My GAD antibodies were positive, what does that mean for my diagnosis?",
        "Is a random blood sugar of 185 considered high for a non-diabetic?",
        "Doctor mentioned 'Metabolic Syndrome', is that the same as diabetes?",
        "Confused about my lipid panel, triglycerides are through the roof.",
        "My kidney function (GFR) dropped on my last test, is this diabetic nephropathy?",
        "How accurate is the A1C test if I have anemia?",
        "Diagnosed with Gestational Diabetes at 28 weeks, will this go away after birth?",
        "What is a good target range for Time in Range (TIR) on a Dexcom?",
        "Microalbumin/Creatinine ratio is high, doctor wants to re-test.",
        "Is it possible to be misdiagnosed as Type 2 if I'm skinny?",
        "Lab report flagged 'High Glucose' but I ate a candy bar before, did I mess it up?",

        # --- 3. TREATMENT & MEDICATION (Side Effects & Dosing) ---
        "Metformin is tearing my stomach up, I've had diarrhea for 3 days straight.",
        "Can I take my Lantus in the morning instead of at night?",
        "My insurance stopped covering Humalog, is Novolog the exact same thing?",
        "Needles for the pen hurt, can I reuse them to save money?",
        "Ozempic makes me so nauseous I can't eat, does this side effect go away?",
        "Forgot my long-acting insulin last night, should I take it now?",
        "Trulicity injection site is red and itchy, am I allergic?",
        "Doctor wants to put me on a pump (Omnipod) but I'm scared of having something attached to me.",
        "Is it okay to split my Metformin pill in half?",
        "Jardiance is making me pee constantly and I think I have a UTI.",
        "How do I calculate my bolus if I don't know the exact carbs?",
        "Can I drink alcohol while taking Glipizide?",
        "Tresiba vs Levemir: which one causes less nighttime lows?",
        "My pump tubing keeps getting caught on doorknobs, it's driving me crazy.",
        "Running out of test strips, can I buy any brand over the counter?",
        "Afrezza inhaled insulin: does it hurt your lungs?",
        "Is Victoza supposed to be kept in the fridge after opening?",
        "Accidentally took my fast-acting instead of long-acting, what do I do??",
        "Switching from MDI to T-Slim pump, looking for tips.",
        "Can I stop taking insulin if I lose 50 pounds?",

        # --- 4. LIFESTYLE & DIET (Real World Eating) ---
        "Can I still eat pizza if I dose for it?",
        "Is Diet Coke actually okay or does it trick my insulin response?",
        "Going to a wedding, how do I handle the cake and alcohol?",
        "Keto diet lowered my A1C but raised my cholesterol, what gives?",
        "I tried intermittent fasting but my sugar spiked when I finally ate.",
        "Are 'net carbs' real or should I count total carbs?",
        "Best snacks for a movie theater that won't spike me?",
        "Does cinnamon actually help lower blood sugar or is that a myth?",
        "Can I drink beer? I heard light beer is okay.",
        "How do I handle carb counting for home-cooked meals without nutrition labels?",
        "Is fruit bad for me? People say bananas have too much sugar.",
        "Exercise makes my blood sugar drop like a rock, I'm scared to go to the gym.",
        "High protein diet... is it safe for my kidneys?",
        "Artificial sweeteners give me a headache, what's a natural alternative?",
        "Trying to gain muscle but afraid of the carbs in protein shakes.",
        "Coffee spikes my sugar even when I drink it black.",
        "Can I eat sushi? The rice seems to mess me up.",
        "Feeling burned out on tracking every single bite I eat.",
        "Is it safe to do CrossFit with a CGM sensor on?",
        "Does stress cause blood sugar to rise even if I haven't eaten?",

        # --- 5. BLOOD SUGAR MANAGEMENT (Daily Struggles) ---
        "Woke up at 250 mg/dL again, dawn phenomenon is killing me.",
        "I feel totally fine at 60 mg/dL, is that dangerous?",
        "Can't get my sugar down, I've corrected twice and it's still 300.",
        "Dexcom says 'Sensor Error' right when I need it most.",
        "My finger pricks are starting to bruise and callused.",
        "Rollercoaster day: went from 40 to 300 in an hour.",
        "How do I pre-bolus for a meal I haven't ordered yet?",
        "Sick day management: sugar is high but I can't keep food down.",
        "Rage bolused because I was high, now I'm crashing hard.",
        "Compression low on my sensor woke me up at 3am.",
        "Does a hot shower make anyone else's Dexcom read false highs?",
        "My sugar spikes 2 hours after eating, not immediately.",
        "Running a marathon, how do I manage insulin during the race?",
        "Correction factor seems off, 1 unit drops me too much.",
        "How often should I calibrate my CGM?",
        "Blood sugar drops when I sleep, afraid I won't wake up.",
        "Is 110 a good fasting number or should it be lower?",
        "My meter and sensor are 50 points apart, which is right?",
        "Managing blood sugar during your period is impossible.",
        "What is 'stacking insulin' and why is it bad?",

        # --- 6. COMPLICATIONS (Fears & Pain) ---
        "My toes are numb and I'm terrified of amputation.",
        "Eye doctor found background retinopathy, can I reverse it?",
        "Kidney function is declining, am I looking at dialysis?",
        "Having trouble getting an erection, is this the diabetes?",
        "Gastroparesis diagnosis explain why I vomit after meals.",
        "Scared I'm going to go blind, my vision is getting worse.",
        "Foot ulcer won't heal, doctor wants to put me in a boot.",
        "Neuropathy pain in my legs keeps me awake all night.",
        "Gum disease is getting bad, dentist blames the diabetes.",
        "Heart palpitations when my sugar is high.",
        "Charcot foot... never heard of it until my foot collapsed.",
        "Frozen shoulder is apparently common for us?",
        "Loss of sensation in my fingers makes it hard to type.",
        "Frequent UTIs are a nightmare.",
        "Diabetic dermopathy spots on my shins look ugly.",
        "Worried about stroke risk, my dad died from it.",
        "Can diabetes cause dementia? I've read scary studies.",
        "Yeast infections under my breasts, so painful.",
        "Bone density scan showed issues, is that diabetes related?",
        "Silent heart attack... how would I know if I had one?",

        # --- 7. GENERAL (Social & Emotional) ---
        "I hate this disease, I just want a day off.",
        "Discrimination at work because I need breaks to check sugar.",
        "How do I tell a date I have a pump without killing the mood?",
        "School nurse doesn't know how to handle my kid's lows.",
        "Travel tips? TSA always hassles me about my juice boxes.",
        "Diabetes burnout is real, I haven't checked my sugar in a week.",
        "Is Type 2 'the bad kind'? People make jokes and it hurts.",
        "Cost of insulin is literally bankrupting me.",
        "Can I still be a pilot/truck driver with diabetes?",
        "My family keeps acting like the 'food police' at dinner.",
        "Guilt over high numbers is overwhelming.",
        "Where can I donate supplies I don't need anymore?",
        "Anyone else feel like a science experiment?",
        "Life insurance premiums are insane for us.",
        "Finding a therapist who understands chronic illness.",
        "Explaining low blood sugar to coworkers so they don't think I'm drunk.",
        "Support groups for parents of T1D kids?",
        "Pregnancy with Type 1... is it high risk?",
        "The stigma around sugar causing diabetes is annoying.",
        "How do I get a free medical ID bracelet?"
    ],
    'Intent': [
        # NOTE: You must match the length. Since I provided ~22 examples per intent above,
        # you would need 22 corresponding labels for each section.
        # Example structure:
        "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms", "symptoms",
        "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports", "diagnosis_and_reports",
        "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication", "treatment_and_medication",
        "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet", "lifestyle_and_diet",
        "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management", "blood_sugar_management",
        "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications", "complications",
        "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general", "general"
    ]
}

# %%
data_2 = pd.DataFrame(data_2)
print(data_2.head(),
data_2.shape)
# Out:
#                                                Query    Intent
# 0  I'm literally thirsty all the time, I drank 3 ...  symptoms
# 1  My vision gets super blurry specifically after...  symptoms
# 2  I've been peeing like a racehorse every hour, ...  symptoms
# 3  My feet feel like they are burning or on fire ...  symptoms
# 4  I have this weird fruity taste in my mouth and...  symptoms (142, 2)

# %%
# @title
data_3_0 = {
    "Query": [
        "My recent fasting glucose result came back high; what does that usually indicate?",
        "My HbA1c is slightly elevated—what does that mean for diabetes risk?",
        "How should I interpret my post-meal glucose readings?",
        "My doctor asked me to repeat my HbA1c test—why would that be necessary?",
        "What does an oral glucose tolerance test check for in diabetes?",
        "Are continuous glucose monitor readings more reliable than fingersticks?",
        "My lab report shows borderline fasting sugar—what does ‘borderline’ mean?",
        "Does a slightly high fasting glucose always indicate prediabetes?",
        "What does it mean if my HbA1c stayed the same for 3 months?",
        "My random glucose reading was high—should I be concerned?",
        "How can I understand my CGM time-in-range percentage?",
        "My triglycerides are high—could this relate to diabetes?",
        "My urine test showed glucose—what does that typically mean?",
        "What does a low C-peptide level indicate in diabetes?",
        "My doctor ordered a GAD antibody test—what is it used for?",
        "Should I be worried if my fasting sugar fluctuates a lot?",
        "My glucose levels spike after breakfast—what could that mean?",
        "What does ‘impaired fasting glucose’ mean in a lab report?",
        "My HbA1c dropped slightly—does that mean improvement?",
        "Why does my CGM show nighttime spikes?",
        "My blood report says ‘insulin resistance’—how is that measured?",
        "What does ‘fasting insulin level’ indicate?",
        "My A1c is normal but fasting sugar is high—how is that possible?",
        "Why do doctors order lipid panels for diabetes patients?",
        "My CGM shows rapid drops after meals—is that normal?",
        "What does a fructosamine test measure?",
        "My fasting sugar is high but I feel fine—what does that mean?",
        "What does a high HOMA-IR score indicate?",
        "Why is post-meal sugar more important in some cases?",
        "My HbA1c is lower than my meter readings—why the difference?",
        "How accurate are home glucometers compared to lab tests?",
        "My blood pressure was high during my diabetes checkup—why is this monitored?",
        "What does microalbumin in urine indicate for diabetics?",
        "My eye test showed mild changes—does this relate to diabetes?",
        "Why did my doctor order a kidney function test?",
        "My cholesterol levels changed—how does this link to diabetes?",
        "What does it mean if my fasting glucose increases slowly each year?",
        "Why do doctors repeat HbA1c every 3 months?",
        "My doctor ordered an ECG during my diabetes review—why?",
        "What does a high post-lunch reading indicate specifically?",
        "My CGM graph shows sudden spikes—what could cause this?",
        "How should I read the ‘average glucose’ on lab reports?",
        "My A1c increased slightly—should I be worried?",
        "Why is vitamin B12 checked for people with diabetes?",
        "My fasting sugar is normal but post-meal is very high—what does that mean?",
        "What does my CGM ‘glycemic variability’ chart represent?",
        "My insulin levels are high—what does that indicate?",
        "How can I tell if my glucose meter is giving accurate readings?",
        "Why do my morning glucose readings remain higher than night readings?",
        "My blood report says mild inflammation—does diabetes influence this?",
        "What does it mean if my HbA1c dropped without lifestyle changes?",
        "My lab glucose was different from my home reading—why?",
        "Why am I asked to test fasting and post-meal sugar separately?",
        "What does a borderline A1c mean for long-term health?",
        "My CGM shows ‘compression lows’—what does this mean?",
        "Why did my doctor recommend an oral glucose tolerance test again?",
        "My kidney numbers changed slightly—how does diabetes affect this?",
        "What does a rising fasting insulin level indicate?",
        "My A1c and fasting sugar don’t match—why?",
        "Why did my report include liver function tests in a diabetes check?",
        "What does it mean if my blood sugar is high only in the morning?",
        "My eye screening report mentioned early changes—what does that mean?",
        "My urine test detected protein—could this relate to diabetes?",
        "Why do doctors check nerve function for diabetes?",
        "What does it mean if my glucose drops quickly after peaking?",
        "My A1c rose even though my daily readings are okay—how?",
        "What is the significance of ‘time above range’ in CGM results?",
        "My report mentioned ‘metabolic syndrome’—how is this linked to diabetes?",
        "Why does my fasting glucose vary from day to day?",
        "What does a high fasting glucose but normal A1c suggest?",
        "My CGM alarms frequently—should I adjust anything?",
        "What does post-dinner glucose tell doctors?",
        "Why is cholesterol testing important for people with diabetes?",
        "My GTT result showed delayed peak—what does that mean?",
        "Why does my CGM show sharp drops after workouts?",
        "What does it mean if sugar levels rise even without eating?",
        "My HbA1c improved but fasting sugar did not—why?",
        "What does an ACR (albumin-creatinine ratio) test show?",
        "My lipid panel changed even though my diet didn’t—why?",
        "Why is blood pressure part of diabetes monitoring?",
        "What does ‘prediabetes range’ mean on a report?",
        "My fasting sugar was normal but random sugar was high—why?",
        "What does a low fasting insulin level usually indicate?",
        "My doctor mentioned ‘insulin sensitivity’—how is it measured?",
        "What does the estimated average glucose on a report mean?",
        "Why are repeat tests needed for diagnosing diabetes?",
        "My CGM trend arrows confuse me—what do they indicate?",
        "What does it mean when my morning readings are always high?",
        "My urine test detected ketones—what could that indicate?",
        "Why do I need an annual eye exam for diabetes?",
        "What does a creatinine number indicate for diabetes management?",
        "My GTT results look unusual—how should they be interpreted?",
        "Why does my sugar spike even with small carb intake?",
        "What does the term ‘glucose excursion’ mean?",
        "My A1c stayed exact same—does that show stability?",
        "Why is a neuropathy test recommended for diabetes?",
        "My CGM sensor reading differs from fingerstick—why?",
        "What does a dip in glucose levels before lunch indicate?",
        "Why do I feel symptoms even when reports look okay?",
        "My kidney markers are slightly off—could this be diabetes related?"
    ],
    "Intent": ["diagnosis_and_reports" for i in range(100)]
}
data_3_1 = {
    "Query": [
        "Is metformin usually the first medication prescribed for type 2 diabetes?",
        "Can diabetes medication doses change over time?",
        "How long does it take for metformin to start working?",
        "Are there alternatives to metformin if it causes stomach issues?",
        "Why do doctors sometimes add a second diabetes medication?",
        "How does insulin help control blood sugar in diabetes?",
        "Can diabetes be managed without medication for some people?",
        "What’s the difference between short-acting and long-acting insulin?",
        "If I forget a diabetes pill, should I take it later or skip it?",
        "How do GLP-1 medications help with blood sugar control?",
        "Why do some diabetes medications help with weight loss?",
        "Can diabetes medication cause low blood sugar?",
        "What should I do if I accidentally take extra diabetes medication?",
        "How do SGLT2 inhibitors affect glucose levels?",
        "How long does insulin remain effective after opening?",
        "Do diabetes medicines interact with blood pressure medications?",
        "Why does my doctor want to switch me to a different diabetes drug?",
        "Do I need to take diabetes medication at the same time daily?",
        "What happens if my medication stops controlling my sugar effectively?",
        "Is it normal to adjust insulin doses frequently?",
        "Can exercise reduce my need for diabetes medication?",
        "What are the side effects of long-term metformin use?",
        "Can I stop diabetes medication if my sugar improves?",
        "How do I know if my insulin dose is correct?",
        "What is the purpose of basal insulin in diabetes treatment?",
        "Why did my doctor add a meal-time insulin?",
        "Can certain diabetes medicines affect appetite?",
        "What should I do if insulin causes redness or swelling?",
        "Are generic diabetes medications as effective as name brands?",
        "Do GLP-1 injections need to be given at the same time each week?",
        "What happens if I miss my weekly diabetes injection?",
        "Can herbal supplements interfere with diabetes medication?",
        "Why does my doctor monitor kidney health before prescribing some medications?",
        "How do DPP-4 inhibitors help with diabetes control?",
        "Can diabetes medicines cause dehydration?",
        "Should I eat before taking my diabetes pill?",
        "What is the difference between metformin and extended-release metformin?",
        "How do I store insulin when traveling?",
        "Why might a doctor switch from tablets to injections?",
        "What is insulin resistance, and how does medication address it?",
        "Can some medications improve insulin sensitivity?",
        "Why do some diabetes drugs help protect heart health?",
        "Can diabetes medication cause dizziness?",
        "How do I rotate injection sites correctly for insulin?",
        "Is there a best time to take metformin for fewer stomach issues?",
        "Why does insulin need to be injected instead of taken as a pill?",
        "Can pain relievers affect my diabetes medication?",
        "What should I do if my insulin pen malfunctions?",
        "Why am I experiencing low blood sugar after starting new medication?",
        "Can I prefill insulin syringes for convenience?",
        "How does my doctor decide which diabetes medication I need?",
        "Why is my doctor increasing my insulin dose gradually?",
        "Can hydration affect how my medication works?",
        "Do I need to adjust medication during illness?",
        "How can I avoid side effects from GLP-1 injections?",
        "What are the signs that I need a treatment adjustment?",
        "Is combination diabetes medication effective?",
        "How long does it take to see results from a new medication?",
        "Why do some diabetes drugs reduce cardiovascular risks?",
        "Can insulin cause weight gain?",
        "Why does my medication require regular liver tests?",
        "How should I dispose of used needles safely?",
        "What are common side effects of SGLT2 inhibitors?",
        "Why does my doctor prescribe multiple low-dose medications instead of one high-dose?",
        "How can I tell if medication is causing fatigue?",
        "Should insulin be taken before meals or after?",
        "Why did my doctor stop one medication and start another?",
        "What happens if I take GLP-1 medication late?",
        "Can diabetes medications affect sleep?",
        "Are insulin pens better than syringes?",
        "Do I need to change medication if my activity level changes?",
        "Why is my medication not lowering fasting sugar enough?",
        "Can long-term medication use affect vitamin levels?",
        "How do I manage nausea from metformin?",
        "Is it safe to combine diabetes medication with supplements?",
        "Why might insulin requirements change suddenly?",
        "Can dehydration increase the effect of diabetes medication?",
        "What is the purpose of correction-dose insulin?",
        "How can I reduce injection pain?",
        "Can diabetes medication cause frequent urination?",
        "Why do I need medication even if my sugar improves with diet?",
        "What does it mean if I feel shaky after taking my medication?",
        "Can I switch from insulin injections to an insulin pump?",
        "Why did my doctor recommend a weekly injection instead of pills?",
        "How does alcohol affect diabetes medication?",
        "Do I need to adjust insulin when exercising heavily?",
        "Why does my medication require taking with food?",
        "Can I travel with insulin through airport security?",
        "What happens if insulin freezes accidentally?",
        "Should I change my dose when fasting for religious reasons?",
        "Why am I still getting high sugars even after medication?",
        "Can anxiety affect how my medication works?",
        "How do I know if a new treatment is helping?",
        "Do diabetes medications expire quickly?",
        "Why is it important to follow a fixed insulin schedule?",
        "Can diabetes treatment cause mood changes?",
        "Should I adjust medication during weight loss?",
        "Why is my doctor concerned about medication adherence?"
    ],
    "Intent": ["treatment_and_medication" for i in range(98)]
}
data_3_2 = {
    "Query": [
        "What are good breakfast options for someone with diabetes?",
        "How many carbs should I aim for in each meal?",
        "Is it okay to eat fruit daily if I have diabetes?",
        "Which snacks help prevent sudden blood sugar spikes?",
        "How can I plan balanced meals for better glucose control?",
        "Is rice safe to eat for people with diabetes?",
        "Which type of bread is better for managing blood sugar?",
        "How often should I exercise to help control diabetes?",
        "What are good evening snacks that won’t raise blood sugar?",
        "Can intermittent fasting be safe for diabetes?",
        "How much walking per day can help lower blood sugar?",
        "Are smoothies okay for someone with diabetes?",
        "Which foods should be avoided for better glucose management?",
        "How can I reduce portion sizes without feeling hungry?",
        "Does drinking water help lower blood sugar?",
        "What is the best time to exercise for stable glucose levels?",
        "Are sugar substitutes safe for people with diabetes?",
        "How can I reduce cravings for sweets?",
        "Can eating late at night affect fasting blood sugar?",
        "Which fruits have the lowest impact on blood sugar?",
        "What is a good pre-workout snack for diabetes?",
        "Do high-protein diets help with blood sugar control?",
        "Can I include potatoes in my diabetic meal plan?",
        "How many meals per day are ideal for diabetes?",
        "Is snacking between meals good or bad for diabetes?",
        "Do nuts help improve blood sugar stability?",
        "How should I structure meals if I’m trying to lose weight with diabetes?",
        "Is it necessary to count calories for diabetes management?",
        "Which cooking oils are healthier for people with diabetes?",
        "Can strength training help improve insulin sensitivity?",
        "What’s the best way to reduce sugar in my daily meals?",
        "Can meditation help with diabetes management?",
        "How does sleep impact blood sugar levels?",
        "Is caffeine safe for people with diabetes?",
        "Can stress cause high blood sugar even with healthy eating?",
        "Are cheat meals okay if I have diabetes?",
        "Which vegetables are best for controlling blood sugar?",
        "Is yogurt a good choice for people with diabetes?",
        "How can I build a weekly meal plan for diabetes?",
        "Do low-carb diets work well for diabetics?",
        "Is it healthy to skip meals with diabetes?",
        "Which exercises help reduce abdominal fat?",
        "Does staying active after meals help with glucose control?",
        "How much fiber should a diabetic eat each day?",
        "What drinks can help avoid blood sugar spikes?",
        "Can I eat pasta if I have diabetes?",
        "Are plant-based diets beneficial for diabetes?",
        "Which foods help improve insulin sensitivity?",
        "Do fermented foods help with diabetes?",
        "Is snacking on fruits better than packaged snacks?",
        "How can I avoid overeating during social gatherings?",
        "What’s the best way to manage diabetes while traveling?",
        "Do soups count as a balanced meal for diabetics?",
        "Is brown sugar healthier than white sugar?",
        "Can deep breathing exercises lower blood sugar over time?",
        "Are overnight oats good for diabetes?",
        "How many steps per day help with diabetes control?",
        "Can dehydration raise blood sugar?",
        "What is a good post-meal routine to keep glucose stable?",
        "Are energy drinks harmful for diabetes management?",
        "Do portion plates help with diabetes control?",
        "Is it okay to eat dessert occasionally with diabetes?",
        "What low-carb snacks can I keep at work?",
        "Does alcohol affect blood sugar significantly?",
        "Is switching to whole grains necessary for diabetes?",
        "Can yoga help lower blood sugar?",
        "Is peanut butter safe for people with diabetes?",
        "How can I build a diet that supports weight loss and diabetes control?",
        "Do high-fat foods affect blood sugar?",
        "What is the best dinner option for steady overnight glucose?",
        "How do I manage diabetes during festivals and celebrations?",
        "Is coconut water good or bad for diabetes?",
        "Do smoothies without sugar still raise blood sugar?",
        "How can I eat out at restaurants without spiking my glucose?",
        "What are easy lunch ideas for diabetes management?",
        "Can I eat bananas with diabetes?",
        "Does walking immediately after eating help lower sugar?",
        "Are low-carb tortillas a good substitute for bread?",
        "What foods help prevent early-morning high glucose?",
        "Can mental stress undo the benefits of healthy eating?",
        "How do I balance carbs and protein in each meal?",
        "Which foods help maintain stable blood sugar overnight?",
        "Is honey okay for diabetics if used sparingly?",
        "What are good alternatives to sugary beverages?",
        "How can I avoid overeating when stressed?",
        "Do home workouts help with diabetes management?",
        "How often should I check my blood sugar when modifying my diet?",
        "Are eggs a good breakfast option for diabetes?",
        "What’s a safe amount of fruit to eat in a day?",
        "Do green leafy vegetables help lower blood sugar?",
        "Can climbing stairs help reduce after-meal glucose spikes?",
        "Is low-fat milk better than full-fat for diabetes?",
        "What herbs may support healthy blood sugar levels?",
        "Does having protein with every meal help blood sugar?",
        "How can I reduce my reliance on processed foods?",
        "Can mindful eating help prevent overeating?",
        "Which foods keep you full longer without raising glucose?"
    ],
    "Intent": ["lifestyle_and_diet" for i in range(97)]
}
data_3_3 = {
    "Query": [
        "Why do I feel extremely thirsty even after drinking a lot of water lately?",
        "I’ve been urinating more frequently than usual—could this be related to diabetes?",
        "Why are my hands and feet tingling more often these days?",
        "My vision gets blurry sometimes, especially after meals—is this a diabetes symptom?",
        "I feel unusually tired even without much activity—does diabetes cause this?",
        "Why do I feel hungry again right after eating?",
        "Is unexplained weight loss a sign of high blood sugar?",
        "My skin is getting very dry and itchy—could this be from diabetes?",
        "I get headaches when I skip meals—does that relate to blood sugar levels?",
        "Why do I feel shaky when I haven't eaten for a few hours?",
        "I wake up with numb feet—can early diabetes cause this?",
        "My cuts and scratches take a very long time to heal—is this common with diabetes?",
        "Why do my legs feel heavy and weak lately?",
        "I’m sweating more than usual—could high blood sugar cause this?",
        "I feel dizzy when standing up quickly—is this connected to diabetes?",
        "Why does my mouth feel unusually dry, even at night?",
        "I get sudden cravings for sweets—does that indicate sugar imbalance?",
        "Why do my hands tremble before meals?",
        "My skin is getting dark patches on the neck area—does this relate to diabetes?",
        "I’ve been feeling nauseous after meals—could that be a diabetes symptom?",
        "Why do I wake up feeling exhausted even after good sleep?",
        "Is constant fatigue a sign of rising blood sugar?",
        "My feet feel cold more often than usual—could diabetes cause this?",
        "I’m experiencing frequent yeast infections—does high blood sugar cause that?",
        "Why do my gums feel sore and bleed more often?",
        "I’ve been losing a lot of hair recently—can diabetes cause this?",
        "I feel a burning sensation in my feet sometimes—is this a diabetes symptom?",
        "Why do I feel lightheaded after eating carbs?",
        "My hands get numb in the morning—does this relate to diabetes?",
        "I get frequent headaches in the afternoon—is this blood-sugar related?",
        "My skin is becoming more sensitive—does this happen with diabetes?",
        "Why do I feel extremely tired after eating sweets?",
        "I have a fruity smell in my breath sometimes—what could that indicate?",
        "Why do I feel out of breath even with mild activity?",
        "I’ve been waking up often at night to use the bathroom—could that be diabetes?",
        "My feet sometimes feel like they’re burning—what does that mean?",
        "I get sudden blurred vision when my sugar drops—is this normal?",
        "Why do I feel anxious and shaky before meals?",
        "My tongue feels dry even after drinking water—is this sugar related?",
        "I’ve noticed sudden weight gain—does blood sugar fluctuation cause that?",
        "Why do I keep getting muscle cramps at night?",
        "My hands feel pins-and-needles after long walks—is that diabetes?",
        "I get dizzy spells when I delay meals—what does that mean?",
        "Why do I feel overly tired in the evenings even without much work?",
        "My ears ring when I feel low energy—can this be blood sugar related?",
        "I’ve been sweating unexpectedly at random times—does this relate to sugar levels?",
        "Why is my skin healing slower than before?",
        "I’m feeling more thirsty after salty foods—does diabetes make this worse?",
        "Why do I get shaky hands after drinking coffee?",
        "I have sudden mood swings—can unstable blood sugar cause that?",
        "My vision becomes cloudy in the afternoon—what might that indicate?",
        "Why do my legs feel restless at night?",
        "I’ve been feeling unusually hungry even after big meals—could this be diabetes?",
        "My feet swell in the evening—can this be a symptom of diabetes?",
        "Why do I feel extremely tired after walking short distances?",
        "My skin is peeling around my toes—does diabetes affect skin this way?",
        "I feel weak and cold before meals—is this low blood sugar?",
        "Why do I feel sleepy every time I eat rice or bread?",
        "My hands get stiff in the morning—could this be from high sugar levels?",
        "I’ve been experiencing random tingling in my arms—is this diabetes?",
        "Why do I feel nauseous when my stomach is empty?",
        "I get headaches if I don’t eat on time—does blood sugar cause this?",
        "Why do I have trouble focusing after eating sugary foods?",
        "My feet feel unusually warm sometimes—is this related to diabetes?",
        "I’ve been feeling jittery more often—what could this mean?",
        "Why do I feel excessively sweaty after mild activities?",
        "I keep waking up very thirsty—could this be diabetes?",
        "My mouth tastes sweet sometimes—what could cause that?",
        "Why do I get cramps during the night more frequently?",
        "I’ve been shaky and irritable before meals lately—could this be blood sugar?",
        "My hands feel weak—does diabetes affect muscle strength?",
        "Why do my feet feel numb in cold weather but normal indoors?",
        "I’ve been having frequent urination—could this mean high blood sugar?",
        "Why do I get out of breath easily lately?",
        "My skin bruises easily now—does diabetes cause this?",
        "I feel jittery after drinking sugary drinks—why?",
        "My head feels heavy when I’m hungry—is this normal with diabetes?",
        "Why do I have sudden sweating attacks for no reason?",
        "I’ve been feeling restless and shaky before lunch—could this be low sugar?",
        "My joints feel stiff more often—can this be related to diabetes?",
        "Why do I feel extremely tired after climbing stairs?",
        "My breath feels unusually dry—can this be a sugar symptom?",
        "I’ve been feeling lightheaded more frequently—what does this mean?",
        "Why do I keep getting minor infections?",
        "I feel extremely tired after waking up—does diabetes cause fatigue?",
        "My feet feel numb after sitting for long—what might this suggest?",
        "Why do I get shaky after long walks?",
        "I’ve been feeling unusually cold lately—could this be sugar related?",
        "Why does my stomach feel bloated after eating carbs?",
        "I get headaches late at night—could this be blood sugar?",
        "My tongue feels unusually dry in the mornings—is this a symptom?",
        "Why do I lose energy suddenly in the afternoon?",
        "I’ve been getting tingling sensations in my fingertips—what could this be?",
        "Why do my calves hurt after mild exercise?",
        "My hands get numb when I wake up—could this relate to diabetes?",
        "Why do I feel thirsty immediately after waking up?"
    ],
    "Intent": ["symptoms" for i in range(96)] }

data_3_4 = {
    "Query": [
        "How can I prevent my blood sugar from rising too high after meals?",
        "Why does my fasting sugar stay high even when my daytime readings are normal?",
        "What is the best way to control sudden spikes in blood sugar?",
        "How often should I check my glucose levels during the day?",
        "What is a normal post-meal blood sugar reading for someone with diabetes?",
        "How can I keep my blood sugar steady throughout the day?",
        "What should I do if my sugar suddenly drops?",
        "Why does my blood sugar rise early in the morning?",
        "How can I manage high blood sugar without immediately adjusting medication?",
        "What lifestyle habits help stabilize glucose levels?",
        "Why does my blood sugar spike after eating certain foods?",
        "What is the best snack to treat low blood sugar safely?",
        "Can stress cause sudden high blood sugar?",
        "How do I prevent sugar crashes after meals?",
        "Why do I get high readings even when I eat healthy?",
        "How does hydration affect my blood sugar levels?",
        "Is it normal for blood sugar to fluctuate throughout the day?",
        "What activities help quickly lower high blood sugar?",
        "How can I understand my continuous glucose monitor trends?",
        "How do I manage blood sugar during travel or irregular routines?",
        "Why does my sugar stay high when I’m sick?",
        "How can I avoid over-correcting low blood sugar?",
        "Which foods raise blood sugar slowly and steadily?",
        "What’s the safest way to bring down very high blood sugar?",
        "Why do high-fat meals cause delayed glucose spikes?",
        "How can I control blood sugar after eating rice or bread?",
        "Why does lack of sleep affect my glucose readings?",
        "What small habits can help reduce daily glucose variability?",
        "Why does exercise sometimes raise my blood sugar instead of lowering it?",
        "How can I reduce blood sugar spikes during stressful days?",
        "What should I do if my glucose remains high despite medication?",
        "How can I balance carbs and activity to avoid sugar spikes?",
        "Why do my post-meal sugars change from day to day?",
        "What are signs that my blood sugar is dropping too fast?",
        "How can I stabilize my sugar overnight?",
        "Why does my blood sugar rise even when I skip meals?",
        "What are good bedtime snacks to prevent nighttime lows?",
        "How can I prevent glucose spikes when eating out?",
        "Why do high-intensity workouts affect my blood sugar differently?",
        "What’s the best way to avoid morning blood sugar spikes?",
        "How do I read and use CGM trend arrows effectively?",
        "Why do I get low blood sugar after long walks?",
        "What can I do to reduce large fluctuations in glucose levels?",
        "How should I space my meals to avoid sugar swings?",
        "Why does caffeine raise my blood sugar occasionally?",
        "How do I keep sugar under control during long workdays?",
        "Can dehydration lead to sudden high blood sugar?",
        "What foods help slow down glucose absorption?",
        "Why does my sugar go high after emotional stress?",
        "How can I curb late-night blood sugar increases?",
        "What is the best routine to keep glucose stable before bedtime?",
        "Why do I feel symptoms even when my sugar is only slightly low?",
        "How can I prevent reactive hypoglycemia after carb-heavy meals?",
        "Why does my glucose stay elevated after a big meal?",
        "What is the healthiest way to treat a mild low blood sugar episode?",
        "Why do certain fruits spike my sugar more than others?",
        "How do I reduce blood sugar when I cannot exercise?",
        "Why does my blood sugar rise after sitting too long?",
        "How can I control blood sugar during fasting periods?",
        "What foods are best for keeping my morning sugar stable?",
        "Why does stress before sleeping cause high morning readings?",
        "How can I avoid glucose spikes at work lunches?",
        "Why do my readings differ between my meter and CGM?",
        "How do I manage blood sugar when eating high-carb meals occasionally?",
        "Why does my sugar go high after a nap?",
        "How can I prevent sudden glucose drops during exercise?",
        "Why is my sugar high even after taking medication on time?",
        "How can I improve my time-in-range on CGM?",
        "What routine helps maintain stable sugar during busy days?",
        "Why do I get sugar crashes after high-protein meals?",
        "How can I adjust my meals to reduce post-meal glucose levels?",
        "Why does overeating cause prolonged high sugar?",
        "How can I manage blood sugar on days when I can’t exercise?",
        "What’s the best way to avoid blood sugar rising late at night?",
        "Why does my sugar rise after emotional arguments or anxiety?",
        "How can I avoid large spikes from restaurant foods?",
        "Why do I get random low sugars even when eating regularly?",
        "What habits help maintain stable sugar on weekends?",
        "How much fiber helps with regulating glucose levels?",
        "Why does blood sugar drop suddenly after taking a walk?",
        "What should I do when my post-meal sugar stays high for hours?",
        "Why do sugary drinks cause rapid spikes?",
        "How can I normalize blood sugar after holiday eating?",
        "Why do blood sugar levels rise before meals sometimes?",
        "How can I correct high blood sugar without causing a low later?",
        "Why does skipping breakfast raise my sugar?",
        "How can I control my blood sugar when working night shifts?",
        "Why does my glucose rise during long commutes?",
        "How can I prevent nighttime glucose dips?",
        "Why do I get high blood sugar after eating small portions?",
        "How can I avoid spikes when eating fruit?",
        "Why do I wake up with high glucose even after a healthy dinner?",
        "How can I keep blood sugar stable during stressful exams or deadlines?",
        "Why do my post-workout sugars rise sometimes?",
        "How can I prevent blood sugar jumps after snacks?",
        "Why does my sugar fluctuate when I don’t sleep well?",
        "How can I avoid morning glucose spikes on weekends?",
        "Why do cold drinks sometimes cause sugar drops?",
        "How can I manage glucose better during busy travel days?"
    ],
    "Intent": ["blood_sugar_management" for i in range(99)]
}
data_3_5 ={
    "Query": [
        "Why do people with diabetes need regular eye checkups?",
        "What are early signs of nerve damage in diabetes?",
        "Why do my feet feel numb sometimes?",
        "How can I prevent diabetes-related foot problems?",
        "What causes tingling sensations in my hands and feet?",
        "Is blurry vision a common issue with diabetes?",
        "Why does high blood sugar affect my eyesight?",
        "What are early warning signs of kidney issues in diabetes?",
        "How often should I check my feet for changes?",
        "Can diabetes cause skin problems?",
        "What does it mean if cuts take longer to heal?",
        "Why do my legs feel heavy sometimes?",
        "How can I avoid long-term complications from diabetes?",
        "What is diabetic neuropathy and how does it develop?",
        "What are signs that my kidneys may be affected?",
        "Why does diabetes increase the risk of infections?",
        "How can I protect my nerves from long-term damage?",
        "Is constant fatigue a complication of diabetes?",
        "Why do my feet sometimes feel cold?",
        "What causes burning sensations in the feet?",
        "How can I reduce the risk of heart disease with diabetes?",
        "Why does diabetes increase heart-related risks?",
        "What are the signs of poor circulation in diabetes?",
        "Can diabetes lead to digestive issues?",
        "Why do I sometimes experience numbness in my fingertips?",
        "How can I identify early kidney damage?",
        "What is diabetic retinopathy and how is it detected?",
        "Why do my muscles feel weak at times?",
        "How does diabetes affect dental health?",
        "Why is gum health important for people with diabetes?",
        "What might cause sudden changes in my vision?",
        "Why do my legs cramp at night?",
        "Can high blood sugar affect my skin’s sensitivity?",
        "Why do my feet feel like they’re burning?",
        "What does swelling in the ankles mean for someone with diabetes?",
        "Are frequent urinary infections related to diabetes?",
        "Why do I feel tingling more at night?",
        "How can I reduce risk of nerve damage over time?",
        "Can diabetes cause digestive slowing?",
        "Why are foot ulcers more common in people with diabetes?",
        "What should I do if I notice redness on my feet?",
        "Why does diabetes sometimes cause numbness on one side only?",
        "How can I protect my eyes from diabetes complications?",
        "What are signs that I might be developing neuropathy?",
        "Why do my toes feel a pins-and-needles sensation?",
        "How does diabetes increase stroke risk?",
        "What should I look for during daily foot checks?",
        "Why does my skin feel dry more often?",
        "Can diabetes affect my hearing?",
        "Why do I feel pain when walking short distances?",
        "What does recurring swelling in my legs indicate?",
        "How can I keep my kidneys healthy with diabetes?",
        "Why do my fingers sometimes feel weak?",
        "What does recurring blurry vision mean?",
        "Why do cuts or bruises appear more often on my legs?",
        "Can diabetes cause balance issues?",
        "Why does my skin itch more frequently?",
        "What causes sharp shooting pains in the feet?",
        "How can I prevent long-term nerve issues?",
        "What is the connection between diabetes and high blood pressure?",
        "Why do I feel burning sensations especially at night?",
        "Can diabetes affect my hands in the same way as my feet?",
        "What are signs of early heart stress in diabetics?",
        "Why do I get swollen feet after long days?",
        "What does frequent urination indicate for kidney health?",
        "Why does poor blood flow happen with diabetes?",
        "Can diabetes cause sudden drops in energy?",
        "Why do my feet feel unusually sensitive sometimes?",
        "What are early symptoms of diabetic foot problems?",
        "Why does high sugar affect nerve signaling?",
        "How do I prevent foot infections?",
        "Why do I sometimes lose feeling in certain toes?",
        "What causes sudden pain in the calf?",
        "Why do I sometimes feel pressure in my chest?",
        "Can diabetes cause problems with digestion speed?",
        "How do I know if my kidneys are under stress?",
        "Why do my gums bleed more than before?",
        "What does tingling after long walks indicate?",
        "Why do my fingers feel stiff in the morning?",
        "Can diabetes affect the way my skin heals?",
        "Why do I get frequent yeast infections?",
        "What are signs of circulation issues in the feet?",
        "Why does my skin bruise easily now?",
        "Can diabetes cause reduced foot sensation over time?",
        "Why do my legs feel restless at night?",
        "What causes sudden sharp pains in the toes?",
        "Why do I feel faint after climbing a few stairs?",
        "How can I protect my heart when managing diabetes?",
        "Why does my vision fluctuate during the day?",
        "What causes numb patches on my skin?",
        "Can diabetes increase risk of nerve compression?",
        "Why do my feet feel puffy sometimes?",
        "How can I reduce swelling caused by poor circulation?",
        "Why do I sometimes feel pulses in my feet?",
        "What causes cold sensitivity in the hands and feet?",
        "Why do I get muscle cramps even when hydrated?",
        "Can diabetes cause slow stomach emptying?",
        "What early signs warn of possible complications?",
        "Why do my arms sometimes feel tingly?",
        "How can I monitor myself for nerve-related issues?"
    ],
    "Intent": ["complications" for i in range(100)]
}
data_3_6 ={
    "Query": [
        "What are the main types of diabetes?",
        "How is diabetes usually diagnosed?",
        "Can diabetes develop suddenly?",
        "Is diabetes hereditary?",
        "What are common early signs of diabetes?",
        "Can someone have diabetes without knowing it?",
        "What is the difference between type 1 and type 2 diabetes?",
        "How often should someone with diabetes check their health?",
        "Can diabetes be reversed with lifestyle changes?",
        "What causes blood sugar to rise unexpectedly?",
        "Is diabetes a lifelong condition?",
        "What role does insulin play in diabetes?",
        "How does stress affect diabetes?",
        "Can someone with diabetes live a normal life?",
        "What common myths about diabetes are untrue?",
        "Do all people with diabetes need insulin?",
        "How does age affect diabetes risk?",
        "Can children develop type 2 diabetes?",
        "Why does diabetes increase risk for other health issues?",
        "Is prediabetes the same as diabetes?",
        "How long does it take to develop diabetes symptoms?",
        "Can weight loss reduce diabetes risk?",
        "What is insulin resistance in simple terms?",
        "Does genetics alone cause diabetes?",
        "Why is diabetes management important?",
        "Can someone with diabetes donate blood?",
        "What is the recommended frequency for full diabetes checkups?",
        "How does diabetes affect daily routines?",
        "Can stress alone raise blood sugar?",
        "Why does diabetes affect energy levels?",
        "Is it possible to have stable sugar without medication?",
        "How does diabetes affect the immune system?",
        "Can diabetes cause mood changes?",
        "What are the long-term goals of diabetes care?",
        "Is there a cure for diabetes?",
        "How does the body regulate sugar normally?",
        "Can people with diabetes eat the same food as others?",
        "Is diabetes more common in certain age groups?",
        "How does physical activity help manage diabetes?",
        "Can diabetes lead to dehydration?",
        "Is it normal for glucose numbers to vary daily?",
        "Can someone have high blood sugar without symptoms?",
        "Does everyone with high sugar eventually develop diabetes?",
        "What role do hormones play in diabetes?",
        "How does diabetes affect metabolism?",
        "Can someone with diabetes travel safely?",
        "Why do regular doctor visits matter for diabetes?",
        "Can people with diabetes fast safely?",
        "Is it possible to outgrow diabetes?",
        "How does sleep impact diabetes control?",
        "Can type 2 diabetes occur in people with normal weight?",
        "Why is diabetes becoming more common?",
        "Can dehydration affect blood sugar?",
        "What is the meaning of remission in diabetes?",
        "Do all diabetics need to avoid sugar completely?",
        "How does diabetes affect appetite?",
        "Is diabetes linked to cholesterol levels?",
        "How does family history influence diabetes risk?",
        "Can diabetes affect concentration?",
        "Why is early diagnosis of diabetes important?",
        "Can diabetes cause fatigue even when controlled?",
        "How do weather changes affect sugar levels?",
        "Can people with diabetes drink alcohol safely?",
        "Why is diabetes considered a chronic condition?",
        "Can blood sugar spike without eating?",
        "Are frequent infections linked to diabetes?",
        "Can mental health impact glucose levels?",
        "Why is hydration important for diabetes?",
        "Can someone have normal fasting glucose but still have diabetes?",
        "How quickly can blood sugar change?",
        "Can diabetes cause headaches?",
        "What medical tests are essential for diabetes care?",
        "Is there a connection between diabetes and thyroid issues?",
        "Does coffee affect glucose levels?",
        "Can anxiety mimic symptoms of high sugar?",
        "Why do blood sugar levels rise after waking up?",
        "Can diabetes cause dizziness?",
        "Is it safe to exercise with high blood sugar?",
        "What is the difference between insulin and glucose?",
        "Can someone with diabetes eat sweets in moderation?",
        "Why are feet commonly affected in diabetes?",
        "Does diabetes affect blood pressure?",
        "Can diabetes cause numbness in hands?",
        "What lifestyle habits help prevent diabetes?",
        "Can someone get diabetes even if they don’t eat much sugar?",
        "How does hydration help regulate sugar?",
        "Can temperature changes affect glucose sensors?",
        "Why do some diabetics have stable sugars while others fluctuate?",
        "Can poor sleep worsen blood sugar control?",
        "Is walking enough exercise for diabetes?",
        "How does diabetes affect healing?",
        "Can viruses trigger diabetes?",
        "Why is A1c monitored in diabetes care?",
        "Can diabetes affect brain function?",
        "Is diabetes more common in men or women?",
        "Why is weight control important for diabetes?",
        "Can diabetes cause joint stiffness?",
        "Is diabetes always preventable?",
        "How does insulin sensitivity vary during the day?",
        "Can diabetes cause muscle weakness?"
    ],
    "Intent": ["general" for i in range(100)]
}



# for i in range(7):
#   x = (globals() [f"data_3_{i}"])
#   print(pd.DataFrame(x))

## Find length of every dictionary data

# for i in range(7):
#   x = globals()[f"data_3_{i}"]
#   print(x['Intent'][0], len(x['Query']))

# %% [markdown]
# # Combine the dictionary into data_3

# %%
data_3 = {'Query' : [], 'Intent' : []}

for i in range(7):
  x = globals()[f"data_3_{i}"]
  for key, values in x.items():
    data_3[key] = data_3[key] + values

# for key, values in data_3.items():
#   print(key, values)
set(data_3['Intent'])
# Out:
# {'blood_sugar_management',
#  'complications',
#  'diagnosis_and_reports',
#  'general',
#  'lifestyle_and_diet',
#  'symptoms',
#  'treatment_and_medication'}

# %% [markdown]
# # Concatinate all the dataframe we have

# %%
def concat_data(num):
  data = pd.DataFrame()
  for i in range(1, num+1):
    x = globals()[f"data_{i}"]
    data = pd.concat([data, pd.DataFrame(x)], axis=0)
  return data

# %%
final_data = concat_data(4)

# %%
final_data.shape
# Out:
# (2387, 2)

# %%
final_data['Intent'].unique()
# Out:
# array(['symptoms', 'diagnosis_and_reports', 'treatment_and_medication',
#        'lifestyle_and_diet', 'blood_sugar_management', 'complications',
#        'general'], dtype=object)

# %% [markdown]
# # Import External Dataset and Concatinate with final_data

# %%
import pandas as pd
ext_data = pd.read_csv("/content/diabetes_intent_natural_queries.csv")
ext_data = ext_data.rename(columns = {'intent':'Intent', 'query':'Query'})
ext_data.head()
# Out:
#      Intent                                              Query
# 0  symptoms               Is muscle cramps a sign of diabetes?
# 1  symptoms          Is frequent urination a sign of diabetes?
# 2  symptoms            Why am I experiencing dizziness lately?
# 3  symptoms  I've been feeling muscle cramps, could it be d...
# 4  symptoms           Why am I experiencing itchy skin lately?

# %%
final_data = pd.concat([final_data, ext_data], axis=0)

# %%
final_data.shape
# Out:
# (2792, 2)

# %% [markdown]
# # Extract another data from the Dictionaries

# %%
# @title
data_dict_1 = {
    "Query": [
    "I am feeling unusually thirsty all the time.",
    "My mouth stays dry even after drinking water.",
    "I urinate more frequently than usual.",
    "I wake up at night to pee multiple times.",
    "I feel extreme tiredness without doing much work.",
    "My vision becomes blurry often.",
    "I get frequent headaches due to fluctuating sugar.",
    "My wounds heal very slowly.",
    "I feel tingling or numbness in my feet.",
    "I am losing weight suddenly without trying.",
    "I feel hungry even after eating a big meal.",
    "My hands feel numb or tingly.",
    "I feel extremely weak in the mornings.",
    "I get tired quickly after walking a short distance.",
    "I am sweating even when it is cool.",
    "My skin is unusually dry and itchy.",
    "I get repeated infections without reason.",
    "I frequently have urinary tract infections.",
    "I feel dizzy when I stand up.",
    "My breath smells fruity or sweet.",
    "I often experience nausea in the morning.",
    "I feel sleepy right after eating food.",
    "I have cramps in my legs at night.",
    "I cannot concentrate on work properly.",
    "I feel mentally foggy most of the time.",
    "I notice dark patches around my neck.",
    "I get yeast infections again and again.",
    "I feel shaky when I skip meals.",
    "I feel sudden sweating and nervousness.",
    "I have unexplained stomach pain.",
    "I get frequent gum infections.",
    "My vision gets darker in the evenings.",
    "I feel exhausted even after sleeping well.",
    "I feel constant dehydration.",
    "I feel pressure or tingling around my toes.",
    "My hands tremble sometimes.",
    "I have recurring skin infections.",
    "I feel bloated and tired after meals.",
    "I notice that small cuts take days to heal.",
    "I feel pain or tingling in my fingertips.",
    "I get sudden hunger pangs.",
    "I feel like fainting when I haven’t eaten.",
    "I notice unusual weakness in my muscles.",
    "I feel chest discomfort after eating sweets.",
    "I feel extreme thirst after salty foods.",
    "I sweat excessively even without exercise.",
    "I get headaches when I delay meals.",
    "My skin feels unusually thin or sensitive.",
    "I feel like my heartbeat is faster sometimes.",
    "I have unexplained itching in my hands and legs.",
    "I feel lethargic throughout the day.",
    "I wake up tired even after 8 hours of sleep.",
    "I feel warmth or burning sensation in my feet.",
    "I experience frequent mood swings.",
    "I get tired immediately after climbing a few steps.",
    "I feel too weak to focus on my tasks.",
    "I get blurry vision during the afternoon.",
    "I frequently feel like I need water.",
    "I feel shaky when my sugar drops.",
    "I have episodes of sudden weakness.",
    "I feel discomfort in my eyes when sugar is high.",
    "My mouth feels sticky due to dryness.",
    "I feel nauseous after eating sugary foods.",
    "I get night sweats more than usual.",
    "I experience heaviness in my arms.",
    "I feel confused when my sugar level drops.",
    "I feel thirsty again soon after drinking water.",
    "My hands feel cold and numb sometimes.",
    "I feel pain in my calves when walking.",
    "I experience tingling-like electric shocks in my feet.",
    "I have noticed swelling in my feet recently.",
    "I constantly feel run down.",
    "I feel sharp pain in my fingers in the morning.",
    "I feel sleepy shortly after breakfast.",
    "I have dry and cracked skin near my heels.",
    "I get headaches after eating heavy meals.",
    "I feel a burning sensation in my palms.",
    "I have difficulty seeing at night.",
    "I feel irritated because of constant fatigue.",
    "My feet feel unusually warm at night.",
    "I feel chills when my sugar suddenly drops.",
    "I feel extremely hungry late at night.",
    "I notice redness and itching in skin folds.",
    "I get sudden cramps in my toes.",
    "I feel like my balance is slightly off sometimes.",
    "I have trouble staying awake after lunch.",
    "I feel short of breath when tired.",
    "I feel pressure behind my eyes sometimes.",
    "I feel tired after drinking sugary drinks.",
    "I notice my urination has increased a lot.",
    "I get frequent mouth ulcers.",
    "I feel like my energy drains suddenly.",
    "I have dryness in my eyes very often.",
    "I feel tingling sensations while resting.",
    "My gums bleed easily when brushing.",
    "I feel unusually weak during the evenings.",
    "I get abdominal discomfort without reason.",
    "I have trouble focusing on simple tasks.",
    "I feel feverish or warm without infection.",
    "I feel restless due to frequent urination."],
    "Intent" : ["symptoms" for i in range(100)]
    }
data_dict_2 = { "Query":[
    "How do I know if I have diabetes?",
    "What tests are required to diagnose diabetes?",
    "Should I get my blood sugar tested?",
    "What is the HbA1c test used for?",
    "What is fasting blood sugar?",
    "What is postprandial blood sugar?",
    "Do I need an OGTT test?",
    "How is diabetes officially diagnosed?",
    "How do doctors confirm diabetes?",
    "What is the normal blood sugar range?",
    "Can I check my sugar at home?",
    "My glucometer shows high sugar, do I have diabetes?",
    "What is the glucose tolerance test?",
    "What is the purpose of random blood sugar test?",
    "Difference between fasting and random sugar?",
    "What HbA1c value indicates diabetes?",
    "How often should I check my blood sugar?",
    "Can urine tests detect diabetes?",
    "What medical tests detect type 1 diabetes?",
    "How to diagnose type 2 diabetes early?",
    "Do I need to repeat sugar tests?",
    "What level of blood sugar is considered diabetic?",
    "Can diabetes be detected without symptoms?",
    "Can a routine checkup diagnose diabetes?",
    "My report shows borderline sugar, what does it mean?",
    "What is prediabetes range?",
    "Difference between diabetes and prediabetes?",
    "What is C-peptide test?",
    "What is insulin resistance test?",
    "How to check insulin levels?",
    "What tests detect gestational diabetes?",
    "When should pregnant women get GTT test?",
    "What is the 75g OGTT test?",
    "Why do doctors order HbA1c instead of fasting?",
    "Is HbA1c enough to diagnose diabetes?",
    "Do I need fasting before HbA1c test?",
    "Why is HbA1c considered reliable?",
    "Is fasting sugar alone enough to diagnose diabetes?",
    "Can diabetes be detected through vision tests?",
    "Do I need cholesterol tests with diabetes diagnosis?",
    "What is the meaning of impaired fasting glucose?",
    "Can stress affect sugar test results?",
    "How to prepare for fasting blood sugar?",
    "What is the accuracy of glucometers?",
    "Can dehydration affect sugar levels?",
    "Should I repeat HbA1c after 3 months?",
    "What is the dawn phenomenon test?",
    "What tests confirm type 1 diabetes antibodies?",
    "What is a GAD antibody test?",
    "What is the ICA-512 test?",
    "Do I need an A1C if fasting is normal?",
    "Can diabetes be misdiagnosed?",
    "Does anemia affect HbA1c reading?",
    "Should I get tested if I feel tired all the time?",
    "My sugar rises after meals, is it diabetes?",
    "What is the 2-hour PP test?",
    "Can CGM detect diabetes?",
    "Are home sugar tests valid for diagnosis?",
    "What is glycemic variability test?",
    "Should children get screened for diabetes?",
    "What tests are needed for elderly screening?",
    "What is fructosamine test?",
    "When is fructosamine preferred over HbA1c?",
    "What is the diagnostic criteria for diabetes?",
    "How many tests confirm diabetes?",
    "My fasting is high but HbA1c is normal, what does it mean?",
    "Can thyroid problems affect sugar diagnosis?",
    "What is the meaning of impaired glucose tolerance?",
    "Should I worry if only post-meal sugar is high?",
    "Do I need a CGM device?",
    "What is the best test for early detection?",
    "My sugar fluctuates, is it diabetes?",
    "What is hypoglycemia and how is it tested?",
    "What is hyperglycemia test?",
    "Can blood sugar test be wrong?",
    "Should I get a second opinion?",
    "Does weight affect test results?",
    "Does infection raise sugar temporarily?",
    "How many hours fasting is required?",
    "What should be fasting for HbA1c?",
    "What is normal RBS level?",
    "Should I test sugar weekly?",
    "What is A1C test frequency?",
    "Can medications affect HbA1c?",
    "Should I test sugar after exercise?",
    "How to interpret glucose report?",
    "My doctor asked for repeat tests, why?",
    "What is the diagnostic cutoff for OGTT?",
    "How important is early diagnosis?",
    "Do I need a liver test while diagnosing diabetes?",
    "My glucose is 140 fasting—do I have diabetes?",
    "My A1C is 6.4—am I diabetic?",
    "Should I test sugar at home daily?",
    "Can I test blood sugar without pricking?",
    "Is CGM better than glucometer?",
    "My glucometer shows error, what to do?",
    "Does food intake before test matter?",
    "Can frequent urination mean diabetes?",
    "Is a single high reading enough for diagnosis?",
    "What test should I do first to diagnose diabetes?"],
    "Intent" : ["diagnosis_and_reports" for i in range(100)]
                }

data_dict_3 = {
    "Query":[
    "What foods should I avoid if I have diabetes?",
    "Can diabetics eat rice daily?",
    "Is fruit safe for people with diabetes?",
    "Give me a proper diabetic diet plan.",
    "What are the best breakfast options for diabetes?",
    "Can I drink fruit juice?",
    "Which vegetables help control blood sugar?",
    "How much sugar is allowed per day?",
    "Can I eat bananas if I have diabetes?",
    "Are apples good for high sugar?",
    "Is chapati better than rice?",
    "Which roti is best for diabetes?",
    "Should diabetics avoid potatoes?",
    "What snacks can diabetics eat?",
    "Are oats healthy for blood sugar?",
    "Is milk good for diabetes?",
    "Can I drink tea with sugar-free?",
    "Is coffee safe for diabetics?",
    "Best foods to lower blood sugar naturally.",
    "What foods cause sudden sugar spikes?",
    "Is brown rice better than white rice?",
    "What is the best diet for type 2 diabetes?",
    "Can diabetics eat sweets occasionally?",
    "Which fruits raise blood sugar quickly?",
    "Healthy lunch menu for diabetic patients.",
    "Is curd good for diabetes management?",
    "Should diabetics avoid bananas?",
    "What is the best morning drink for diabetics?",
    "Can I eat mango if I have diabetes?",
    "Is watermelon safe for sugar control?",
    "How many rotis can a diabetic eat?",
    "Can diabetics eat eggs daily?",
    "What is a low-carb diet for diabetes?",
    "Should I follow a high-protein diet?",
    "Can intermittent fasting help with sugar control?",
    "Is keto diet safe for diabetics?",
    "What are the best dinner options for diabetes?",
    "Can I eat outside food if I have diabetes?",
    "Are biscuits harmful for diabetics?",
    "Is corn good for diabetes?",
    "Should diabetics avoid sugary drinks?",
    "Is jaggery better than sugar?",
    "Are sugar-free desserts safe?",
    "Can I eat idli and dosa?",
    "Which dal is good for diabetics?",
    "Should I avoid fried foods completely?",
    "Is peanut butter good for diabetes?",
    "Can diabetics drink coconut water?",
    "Are dry fruits safe for diabetics?",
    "Best low-sugar fruits for diabetics.",
    "Is popcorn healthy for diabetes?",
    "Can diabetics drink buttermilk?",
    "What foods help reduce insulin resistance?",
    "Should diabetics follow small frequent meals?",
    "What is a diabetic plate method?",
    "Which oils are best for cooking?",
    "Can I eat pasta if I have diabetes?",
    "Are noodles harmful for sugar levels?",
    "Should diabetics avoid soft drinks?",
    "Can I drink alcohol if I have diabetes?",
    "Which salads are best for diabetes?",
    "Can I eat chocolate in small quantity?",
    "Is cheese good or bad for diabetes?",
    "What bread is best for glucose control?",
    "Is multigrain roti better?",
    "Can I eat sugar-free chocolates?",
    "Should diabetics avoid milkshakes?",
    "Is honey safe for people with diabetes?",
    "Are sprouts healthy for diabetics?",
    "Which nuts help control sugar?",
    "Can I eat chana or rajma?",
    "Is semolina (sooji) good for diabetes?",
    "What are low-GI foods?",
    "Should diabetics avoid processed food?",
    "Can I eat meals late at night?",
    "Is green tea helpful for diabetes?",
    "Can diabetics drink lemonade?",
    "What soups are best for diabetes?",
    "Should I reduce salt intake?",
    "Is butter safe for diabetics?",
    "Which cooking method is best for diabetes?",
    "How many fruits per day are allowed?",
    "Can I eat sweet corn?",
    "Is yogurt good for diabetes?",
    "Can diabetics eat grapes?",
    "Foods that prevent sudden sugar drops.",
    "Is paneer good for diabetes?",
    "Should diabetics avoid bakery items?",
    "Can I eat sandwiches?",
    "Is peanut chikki safe for diabetics?",
    "Should I avoid sugary tea?",
    "Best foods to eat before workout for diabetics.",
    "Can diabetics follow vegetarian diet?",
    "Can diabetics follow non-veg diet?",
    "Is fish good for diabetes?",
    "Can I eat chicken regularly?",
    "Are energy drinks safe for diabetics?",
    "Which smoothies are safe for sugar control?",
    "How to plan a full-day diabetic meal chart?",
    "Is fasting good or bad for sugar levels?",
    "How many calories should diabetics eat daily?"],
    "Intent" : ["lifestyle_and_diet" for i in range(101)]
    }

data_dict_4 = {
    "Query":[
    "What are the treatment options for diabetes?",
    "Do I need to start insulin?",
    "How does metformin help control sugar?",
    "Can diabetes be reversed?",
    "How do I reduce high blood sugar quickly?",
    "What to do if my sugar level suddenly goes up?",
    "Is insulin better than tablets?",
    "Can I manage diabetes without medicine?",
    "Are diabetes medicines safe for long term?",
    "I forgot my diabetes medicine, what should I do?",
    "What is the best treatment for type 2 diabetes?",
    "How does insulin work in the body?",
    "What is the safest medicine for diabetes?",
    "Do I need multiple medications for sugar control?",
    "When should I start taking insulin?",
    "Can I stop medicines once sugar becomes normal?",
    "Is diabetes reversible with lifestyle changes?",
    "Can weight loss reduce the need for medication?",
    "What are side effects of metformin?",
    "What are side effects of insulin?",
    "Which medicine is best to control fasting sugar?",
    "Which medicine controls post-meal sugar?",
    "How do diabetes injections work?",
    "What to do during low sugar episodes?",
    "How to treat hypoglycemia at home?",
    "Should I carry glucose tablets?",
    "Is there any cure for type 1 diabetes?",
    "Which doctor should I consult for diabetes?",
    "How often should I adjust my medication?",
    "Is Ayurveda effective for controlling diabetes?",
    "Can homeopathy treat diabetes?",
    "Can herbal supplements help reduce sugar?",
    "Do cinnamon supplements help in diabetes?",
    "Are multivitamins needed for diabetics?",
    "Does Vitamin D help control sugar?",
    "Can probiotics help in diabetes management?",
    "How to treat high morning sugar?",
    "Why is my fasting sugar high even with medicine?",
    "How to reduce insulin resistance?",
    "How long does metformin take to work?",
    "Can I take diabetes medicine at night?",
    "Is it safe to switch diabetes medication?",
    "How to treat diabetes naturally?",
    "Can yoga reduce the need for medicine?",
    "Does walking reduce sugar enough to avoid medicine?",
    "How to treat sugar spikes after meals?",
    "Can intermittent fasting reduce medicine requirement?",
    "Why does my sugar fluctuate even with medication?",
    "What are the new diabetes treatments available?",
    "Is CGM required for better treatment?",
    "Are GLP-1 drugs safe?",
    "What are SGLT2 inhibitors?",
    "What are DPP-4 inhibitors?",
    "Which drug class is safest for the kidneys?",
    "Which drug class reduces weight?",
    "Is insulin harmful if used early?",
    "Does insulin cause weight gain?",
    "How to inject insulin properly?",
    "Where should insulin be injected?",
    "What is basal insulin?",
    "What is bolus insulin?",
    "What is premixed insulin?",
    "When should insulin dose be adjusted?",
    "How often should I check sugar after adjusting medicine?",
    "Can I stop insulin once sugar is controlled?",
    "Does stress affect my treatment?",
    "Why is my sugar high even with treatment?",
    "How to treat gestational diabetes?",
    "Do pregnant women need insulin?",
    "How to treat diabetes in older adults?",
    "What is the treatment for diabetic ketoacidosis?",
    "How to treat extremely high sugar emergency?",
    "Can I manage diabetes without injections?",
    "When do I need oral tablets?",
    "Should I take medicine before or after food?",
    "What time should I take metformin?",
    "How to treat diabetes-related fatigue?",
    "Should I take aspirin along with diabetes medicine?",
    "Do diabetics need cholesterol medicine?",
    "Do diabetics need blood pressure medicine?",
    "How to treat nerve pain caused by diabetes?",
    "How to treat eye problems caused by diabetes?",
    "How to treat diabetic foot?",
    "Can physiotherapy help diabetic neuropathy?",
    "Do I need regular follow-ups with doctor?",
    "How to monitor sugar during treatment?",
    "Should I change medicine if sugar is not controlled?",
    "Is bariatric surgery a treatment option for diabetes?",
    "Can surgery reverse type 2 diabetes?",
    "What is the best long-term treatment for diabetes?",
    "How to treat nighttime high glucose?",
    "How to treat morning low glucose?",
    "Is insulin pump a better treatment?",
    "How to treat diabetes in children?",
    "What to do if sugar drops while sleeping?",
    "How long will I need medication?",
    "Can natural remedies replace diabetes treatment?",
    "Why is treatment different for everyone?",
    "How to personalize diabetes treatment?",
    "Should I take medicine during fasting or illness?",
    "How to treat sugar fluctuations during stress?"],
    "Intent" : ["treatment_and_medication" for i in range(101)]
    }

data_dict_5 = {
    "Query":[
    "What complications can diabetes cause?",
    "Does diabetes cause nerve damage?",
    "Can diabetes affect my eyes?",
    "What is diabetic retinopathy?",
    "Can diabetes lead to kidney failure?",
    "Why do diabetics get foot problems?",
    "What is diabetic neuropathy?",
    "How does high sugar damage nerves?",
    "Does diabetes increase heart disease risk?",
    "Can diabetes cause stroke?",
    "Why do wounds heal slowly in diabetes?",
    "Can diabetes lead to infections?",
    "Is skin itching a complication of diabetes?",
    "What is diabetic foot ulcer?",
    "Can diabetes cause blindness?",
    "Does diabetes cause hair loss?",
    "Can diabetes affect the gums or teeth?",
    "Does diabetes cause dry skin?",
    "What are long-term complications of diabetes?",
    "Can diabetes affect sexual health?",
    "Does diabetes cause erectile dysfunction?",
    "Can women have sexual issues due to diabetes?",
    "Does diabetes cause infertility?",
    "Can uncontrolled diabetes affect pregnancy?",
    "Can babies be affected by mother's diabetes?",
    "What are complications of gestational diabetes?",
    "Is high blood pressure related to diabetes?",
    "Does diabetes affect cholesterol levels?",
    "Can diabetes cause liver problems?",
    "What is diabetic nephropathy?",
    "Can diabetes damage blood vessels?",
    "Does diabetes lead to swelling in legs?",
    "Can diabetes cause numbness in hands?",
    "Why do diabetics feel burning in feet?",
    "What is peripheral neuropathy?",
    "Does diabetes affect digestion?",
    "What is diabetic gastroparesis?",
    "Why do diabetics feel bloated?",
    "Can diabetes cause constipation?",
    "Is diarrhea a complication of diabetes?",
    "Does diabetes affect the brain?",
    "What is diabetic cognitive decline?",
    "Can diabetes cause memory problems?",
    "Does high sugar affect concentration?",
    "Why do diabetics feel tired all the time?",
    "Can diabetes cause dehydration?",
    "Can diabetes lead to kidney stones?",
    "Can diabetes cause anemia?",
    "Does diabetes increase infection risk?",
    "Why do diabetics get UTIs often?",
    "Can diabetes cause yeast infection?",
    "Why do diabetics get skin rashes?",
    "Does diabetes cause gum bleeding?",
    "Can diabetes cause nerve pain?",
    "What is autonomic neuropathy?",
    "Does diabetes affect heart rhythm?",
    "Why is diabetes dangerous for the heart?",
    "Can diabetes cause heart attack?",
    "Does diabetes cause leg cramps?",
    "Can diabetes cause varicose veins?",
    "Is high sugar linked to blood clots?",
    "Does diabetes affect hearing?",
    "Can diabetes cause hearing loss?",
    "Can diabetes cause dizziness?",
    "Does diabetes cause low immunity?",
    "Can diabetes cause sleep problems?",
    "Does diabetes cause sleep apnea?",
    "Can diabetes cause blurry vision suddenly?",
    "Can diabetes cause cataracts?",
    "Does diabetes worsen glaucoma?",
    "Why do diabetics have foot numbness?",
    "Can diabetes cause foot deformities?",
    "What is Charcot foot?",
    "Does diabetes lead to amputations?",
    "Why do diabetics get gangrene?",
    "Can diabetes cause high ketones?",
    "What is diabetic ketoacidosis?",
    "Can DKA be life-threatening?",
    "What is hyperosmolar hyperglycemic state?",
    "Can high sugar cause stroke?",
    "Does diabetes affect blood pressure?",
    "Does diabetes cause erectile problems in men?",
    "Can diabetes cause PCOS symptoms?",
    "Can diabetes cause hormonal imbalance?",
    "Is fatty liver related to diabetes?",
    "Can diabetes cause pancreatic problems?",
    "Why do diabetics feel excessive thirst?",
    "Can diabetes cause mood swings?",
    "Can diabetes cause depression?",
    "Does high sugar affect mental health?",
    "Can complications be prevented?",
    "How to avoid diabetic neuropathy?",
    "How to prevent kidney damage?",
    "How to protect my eyes from diabetes?",
    "How to avoid diabetic foot?",
    "Which complications are reversible?",
    "Can early treatment prevent complications?",
    "What tests detect diabetes complications?",
    "How often should I screen for complications?"],
    "Intent" : ["complications" for i in range(99)]
    }

data_dict_6 = {"Query":[
    "How can I prevent diabetes through lifestyle?",
    "What lifestyle changes help reduce sugar?",
    "Can regular exercise control diabetes?",
    "How much should I walk daily?",
    "What is the best exercise routine for diabetics?",
    "Can yoga help in controlling sugar levels?",
    "How to naturally reduce blood sugar?",
    "What habits increase the risk of diabetes?",
    "How to improve lifestyle for better sugar control?",
    "What is the best daily routine for diabetics?",
    "Can losing weight lower blood sugar?",
    "How much weight should I lose to prevent diabetes?",
    "What are healthy habits for diabetic patients?",
    "Can stress increase blood sugar?",
    "How to manage stress for diabetes control?",
    "Does sleep affect blood sugar?",
    "How many hours of sleep should diabetics get?",
    "How to improve sleep quality with diabetes?",
    "Can drinking water reduce sugar levels?",
    "What is the best time to exercise for diabetes?",
    "How often should diabetics exercise?",
    "Can I lift weights if I have diabetes?",
    "Is running good for diabetics?",
    "Are home workouts effective for diabetes?",
    "Can lifestyle alone manage type 2 diabetes?",
    "How to maintain sugar levels without medicine?",
    "What are healthy morning habits for diabetics?",
    "Is intermittent fasting good for diabetes?",
    "Can skipping meals affect blood sugar?",
    "How to stay active throughout the day?",
    "Does dehydration affect sugar levels?",
    "Can reducing salt help diabetic patients?",
    "How to plan a healthy lifestyle for prediabetes?",
    "What is the best evening routine for diabetics?",
    "Does walking after meals reduce sugar?",
    "Can meditation control blood sugar?",
    "What are simple activities to reduce sugar?",
    "How to reduce sugar cravings?",
    "Does screen time affect diabetes?",
    "Can sitting for long hours raise sugar?",
    "How to avoid sedentary lifestyle?",
    "How to build a healthy fitness routine?",
    "Can dancing help control diabetes?",
    "Is cycling safe for diabetic patients?",
    "Does sunlight exposure help diabetics?",
    "Can improving posture help sugar levels?",
    "Is home yoga effective for diabetes?",
    "What breathing exercises reduce sugar?",
    "Can morning stretching help diabetics?",
    "How to manage diabetes during travel?",
    "How to maintain routine during holidays?",
    "Does alcohol affect lifestyle control for diabetes?",
    "Can quitting smoking improve sugar levels?",
    "Can staying hydrated help maintain sugar?",
    "What lifestyle mistakes diabetics should avoid?",
    "How to build consistency in lifestyle habits?",
    "What activities help reduce insulin resistance?",
    "How much physical activity is needed daily?",
    "Can gardening count as exercise for diabetics?",
    "Does house cleaning reduce sugar levels?",
    "Is swimming good for diabetics?",
    "How to avoid stress-eating for diabetics?",
    "How to build a balanced routine to avoid sugar spikes?",
    "Is it okay to workout at night?",
    "What is the best lifestyle for type 2 diabetes control?",
    "Can lifestyle help reverse prediabetes?",
    "Can I maintain sugar without strict diet if I follow lifestyle properly?",
    "Why do diabetics need daily exercise?",
    "Does deep breathing lower sugar instantly?",
    "How to plan daily schedule for sugar control?",
    "Does traveling affect sugar control?",
    "How to avoid junk food cravings?",
    "Can music therapy help diabetic patients?",
    "How to stay motivated to follow lifestyle changes?",
    "Does being overweight worsen diabetes?",
    "Can I reduce belly fat to control diabetes?",
    "What lifestyle changes improve insulin sensitivity?",
    "Does cold water help reduce sugar?",
    "Can I take naps during the day?",
    "Does poor sleep increase cravings?",
    "How to boost energy naturally with diabetes?",
    "Can morning sunlight help sugar levels?",
    "How to maintain blood sugar throughout the day?",
    "What is the best way to track daily activity?",
    "Should diabetics walk after every meal?",
    "Can sitting on the floor help digestion?",
    "Does overeating increase insulin spikes?",
    "How to avoid late-night eating?",
    "Is climbing stairs good for diabetes?",
    "Can adopting a pet reduce stress and help diabetes?",
    "How to stay physically active at work?",
    "How to improve discipline with lifestyle?",
    "What lifestyle changes prevent complications?",
    "How to maintain sugar levels during festivals?",
    "Does traveling increase sugar fluctuations?",
    "What healthy habits should I develop long-term?",
    "Can lifestyle alone reduce HbA1c?",
    "What is the easiest lifestyle habit to start with?",
    "Can lifestyle changes reduce the need for medication?",
    "How to make lifestyle changes stick permanently?",
    "What daily habits keep sugar stable?"],
    "Intent" : ["lifestyle_and_diet" for i in range(101)]
               }

# %%
final_data_dict = {"Query": [], "Intent" : []}
for i in range(1, 7):
  x = globals()[f"data_dict_{i}"]
  final_data_dict["Query"].extend(x["Query"])
  final_data_dict["Intent"].extend(x["Intent"])

# %% [markdown]
# # Concat with Final data

# %%
final_data = pd.concat([final_data, pd.DataFrame(final_data_dict)], axis=0)
final_data.shape
# Out:
# (3394, 2)

# %% [markdown]
# # Save the final_data DataFrame into CSV File

# %%
final_data.to_csv("Query_and_Intent_data.csv")

# %%
import seaborn as sns
sns.countplot(final_data['Intent'])
# Out:
# <Axes: xlabel='count', ylabel='Intent'>
